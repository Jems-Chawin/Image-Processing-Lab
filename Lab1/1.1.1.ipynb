# %% [markdown]
# Libraries

# %%
# all ipynb files use conda env

# import all necessary libs
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# Read and Show Original Image

# %%
# read the image file
image = cv2.imread("../images/bird.jpg")
plt.imshow(image)

# %% [markdown]
# Convert Image from BGR to RGB Manually

# %%
# convert the original bgr image file to rgb
image_convert = image[:,:,[2,1,0]]

# extract each individual color channel
x_b = image[:,:,0]
x_g = image[:,:,1]
x_r = image[:,:,2]

y_r = image_convert[:,:,0]
y_g = image_convert[:,:,1]
y_b = image_convert[:,:,2]

# %% [markdown]
# Show the Results

# %%
# use subplot
plt.figure(figsize=(12,8))

# BGR image
plt.subplot(2,4,1)
plt.imshow(image)
plt.title("BGR Image")

plt.subplot(2,4,2)
plt.imshow(x_b, cmap="gray")
plt.title("B")

plt.subplot(2,4,3)
plt.imshow(x_g, cmap="gray")
plt.title("G")

plt.subplot(2,4,4)
plt.imshow(x_r, cmap="gray")
plt.title("R")

# RGB image
plt.subplot(2,4,5)
plt.imshow(image_convert)
plt.title("RGB")

plt.subplot(2,4,6)
plt.imshow(y_r, cmap="gray")
plt.title("R")

plt.subplot(2,4,7)
plt.imshow(y_g, cmap="gray")
plt.title("G")

plt.subplot(2,4,8)
plt.imshow(y_b, cmap="gray")
plt.title("B")

# show
plt.tight_layout()
plt.show()
